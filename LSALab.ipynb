# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['soc.religion.christian']
dataset = fetch_20newsgroups(subset='all',shuffle=True, random_state=42, categories=categories)
corpus = dataset.data

# %%
stopset = set(stopwords.words('english'))
stopset.update(['lt','p','/p','br','amp','quot','field','font','normal','span','0gx','rgb','style','51','spacing','text','helvetica','size','family','space','arial','height','lindent','letter','line','none','sans','serif','transform','line','variant','weight','times','strong','new','video','title','white','word','letter','roman','Opt','16','color','12','14','21','neve','apple','class',])

# %%
corpus[0]
# Out:
# u'From: sciysg@nusunix1.nus.sg (Yung Shing Gene)\nSubject: Mission Aviation Fellowship\nOrganization: National University of Singapore\nLines: 3\n\nHi,\n\tDoes anyone know anything about this group and what they\ndo? Any info would be appreciated. Thanks!\n'

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(1,3))
X=vectorizer.fit_transform(corpus)

# %%
X[0]
# Out:
# <1x301759 sparse matrix of type '<type 'numpy.float64'>'
# 	with 72 stored elements in Compressed Sparse Row format>

# %%
print X[0]
# Out:
#   (0, 296340)	0.123882389819
#   (0, 136773)	0.137053533366
#   (0, 121217)	0.137053533366
#   (0, 22469)	0.137053533366
#   (0, 147609)	0.137053533366
#   (0, 22212)	0.129348908299
#   (0, 127146)	0.123882389819
#   (0, 157376)	0.137053533366
#   (0, 246575)	0.137053533366
#   (0, 280276)	0.119642228669
#   (0, 180323)	0.119642228669
#   (0, 191744)	0.119642228669
#   (0, 103620)	0.137053533366
#   (0, 30216)	0.137053533366
#   (0, 175125)	0.137053533366
#   (0, 257962)	0.137053533366
#   (0, 111385)	0.137053533366
#   (0, 243273)	0.137053533366
#   (0, 301544)	0.137053533366
#   (0, 242492)	0.137053533366
#   (0, 185638)	0.137053533366
#   (0, 185647)	0.119642228669
#   (0, 236540)	0.137053533366
#   (0, 24033)	0.119642228669
#   (0, 296338)	0.119642228669
#   :	:
#   (0, 265758)	0.0686976091148
#   (0, 24016)	0.0975401027236
#   (0, 296233)	0.0301177950438
#   (0, 136715)	0.0890597804242
#   (0, 121105)	0.0600617447998
#   (0, 22354)	0.0547611832123
#   (0, 147557)	0.0374501528559
#   (0, 22027)	0.0504212740987
#   (0, 127144)	0.0843689591761
#   (0, 156525)	0.0190019434788
#   (0, 246564)	0.119642228669
#   (0, 280010)	0.0373999495414
#   (0, 180282)	0.0811034703072
#   (0, 191468)	0.0219406283814
#   (0, 103594)	0.0963881170864
#   (0, 30214)	0.129348908299
#   (0, 175121)	0.0898354776567
#   (0, 257580)	0.0190019434788
#   (0, 111377)	0.119642228669
#   (0, 243271)	0.137053533366
#   (0, 301542)	0.137053533366
#   (0, 242476)	0.113248602246
#   (0, 185627)	0.113248602246
#   (0, 185645)	0.119642228669
#   (0, 236538)	0.137053533366

# %%
X.shape
# Out:
# (997, 301759)

# %%
lsa=TruncatedSVD(n_components=30,n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=30, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([ 0.01487088,  0.00700224,  0.00128836, ...,  0.00025395,
#         0.00025395,  0.00025395])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# god
#
# edu
#
# one
#
# jesus
#
# would
#
# people
#
# sin
#
# church
#
# us
#
# com
#
# Concept 1:
# god
#
# christ
#
# 00 08 15
#
# time
#
# life
#
# jesus
#
# point
#
# believe
#
# said
#
# human
#
# Concept 2:
# god
#
# truth
#
# organization
#
# us
#
# homosexual
#
# would
#
# law
#
# paul
#
# faith
#
# com
#
# Concept 3:
# hell
#
# say
#
# lines
#
# writes
#
# christ
#
# organization
#
# 00 08 15
#
# since
#
# heaven
#
# com
#
# Concept 4:
# god
#
# 1993
#
# without
#
# edu
#
# know
#
# could
#
# good
#
# rutgers
#
# law
#
# use
#
# Concept 5:
# faith
#
# even
#
# christian
#
# religion
#
# apr
#
# love
#
# also
#
# believe
#
# way
#
# 00 08 27
#
# Concept 6:
# 00 08 10
#
# faith
#
# people
#
# sin
#
# however
#
# us
#
# make
#
# church
#
# wrong
#
# 1993
#
# Concept 7:
# christ
#
# truth
#
# church
#
# sin
#
# us
#
# rutgers
#
# question
#
# 00 08 10
#
# faith
#
# shall
#
# Concept 8:
# jesus
#
# son
#
# subject re
#
# people
#
# mary
#
# also
#
# christ
#
# need
#
# eternal
#
# organization
#
# Concept 9:
# know
#
# christ
#
# way
#
# 00 08 27
#
# lord
#
# church
#
# psalms
#
# think
#
# 00 08 44
#
# doesn
#
# Concept 10:
# good
#
# also
#
# com
#
# would
#
# come
#
# 00 08 44
#
# even
#
# 00 08 27
#
# writes
#
# true
#
# Concept 11:
# jesus
#
# even
#
# rutgers edu
#
# edu
#
# 00 08 10
#
# subject re
#
# lord
#
# re
#
# subject
#
# people
#
# Concept 12:
# god
#
# church
#
# bible
#
# question
#
# different
#
# christians
#
# really
#
# say
#
# others
#
# rutgers
#
# Concept 13:
# writes
#
# christians
#
# know
#
# university
#
# life
#
# law
#
# athos
#
# athos rutgers
#
# athos rutgers edu
#
# edu
#
# Concept 14:
# even
#
# writes
#
# 00 08 27
#
# university
#
# human
#
# many
#
# god
#
# subject re
#
# read
#
# 00 08 44
#
# Concept 15:
# church
#
# christian
#
# com
#
# christians
#
# never
#
# question
#
# like
#
# rutgers edu
#
# also
#
# different
#
# Concept 16:
# christian
#
# people
#
# com
#
# think
#
# 00 08 15
#
# god
#
# writes
#
# 00 08 33
#
# re
#
# others
#
# Concept 17:
# god
#
# edu
#
# sin
#
# say
#
# 00 08 10
#
# need
#
# things
#
# way
#
# christian
#
# athos
#
# Concept 18:
# way
#
# know
#
# 00 08 33
#
# 00 08 44
#
# us
#
# rutgers edu
#
# bible
#
# article
#
# like
#
# much
#
# Concept 19:
# believe
#
# think
#
# 00 08 47
#
# say
#
# lines
#
# 00 08 35
#
# university
#
# 00 08 27
#
# world
#
# 1993
#
# Concept 20:
# subject re
#
# people
#
# believe
#
# could
#
# one
#
# christians
#
# must
#
# church
#
# god
#
# lines
#
# Concept 21:
# god
#
# think
#
# subject re
#
# jesus
#
# organization
#
# writes
#
# edu
#
# say
#
# re
#
# well
#
# Concept 22:
# 00 08 10
#
# also
#
# christians
#
# god
#
# even
#
# one
#
# seems
#
# 00 08 47
#
# edu
#
# re
#
# Concept 23:
# jesus
#
# know
#
# may
#
# also
#
# said
#
# human
#
# 00 08 15
#
# 00 08 10
#
# 00 08 22
#
# article
#
# Concept 24:
# know
#
# us
#
# would
#
# sin
#
# even
#
# rutgers edu
#
# one
#
# also
#
# jesus
#
# like
#
# Concept 25:
# would
#
# faith
#
# subject re
#
# like
#
# scripture
#
# says
#
# 00 08 22
#
# 00 08 10
#
# said
#
# article
#
# Concept 26:
# 00 08 15
#
# rutgers edu
#
# edu
#
# re
#
# life
#
# would
#
# subject
#
# 00 08 27
#
# us
#
# faith
#
# Concept 27:
# 00 08 35
#
# 00 08 47
#
# see
#
# question
#
# 00 08 22
#
# christian
#
# 00 08 44
#
# really
#
# life
#
# subject re
#
# Concept 28:
# com
#
# subject re
#
# 00 08 10
#
# say
#
# us
#
# 00 08 27
#
# like
#
# bible
#
# christian
#
# 00 08 15
#
# Concept 29:
# 00 08 33
#
# re
#
# 1993
#
# would
#
# christ
#
# christians
#
# 00 08 47
#
# subject re
#
# believe
#
# law

# %%
corpus[1]
# Out:
# u"From: whitsebd@nextwork.rose-hulman.edu (Bryan Whitsell)\nSubject: Re: Satan and TV\nReply-To: whitsebd@nextwork.rose-hulman.edu\nOrganization: News Service at Rose-Hulman\nLines: 14\n\nIn article <May.9.05.41.06.1993.27543@athos.rutgers.edu>  \nsalaris@niblick.ecn.purdue.edu (Rrrrrrrrrrrrrrrabbits) writes:\n> MTV controls what bands are popular, no matter how bad they are.  In fact, it is  \n>better to be politically correct - like U2, Madonna - than to have any musical  \n>talent. \n> Steven C. Salaris                \n \nInteresting idea.  \nRegular televeision seems to do this sort of thing too with politically correct  \nshows.\n\n\nIn Christ's Love\nBryan \n"

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(1,3))
X=vectorizer.fit_transform(corpus)

# %%
X[0]
# Out:
# <1x301759 sparse matrix of type '<type 'numpy.float64'>'
# 	with 72 stored elements in Compressed Sparse Row format>

# %%
print X[0]
# Out:
#   (0, 296340)	0.123882389819
#   (0, 136773)	0.137053533366
#   (0, 121217)	0.137053533366
#   (0, 22469)	0.137053533366
#   (0, 147609)	0.137053533366
#   (0, 22212)	0.129348908299
#   (0, 127146)	0.123882389819
#   (0, 157376)	0.137053533366
#   (0, 246575)	0.137053533366
#   (0, 280276)	0.119642228669
#   (0, 180323)	0.119642228669
#   (0, 191744)	0.119642228669
#   (0, 103620)	0.137053533366
#   (0, 30216)	0.137053533366
#   (0, 175125)	0.137053533366
#   (0, 257962)	0.137053533366
#   (0, 111385)	0.137053533366
#   (0, 243273)	0.137053533366
#   (0, 301544)	0.137053533366
#   (0, 242492)	0.137053533366
#   (0, 185638)	0.137053533366
#   (0, 185647)	0.119642228669
#   (0, 236540)	0.137053533366
#   (0, 24033)	0.119642228669
#   (0, 296338)	0.119642228669
#   :	:
#   (0, 265758)	0.0686976091148
#   (0, 24016)	0.0975401027236
#   (0, 296233)	0.0301177950438
#   (0, 136715)	0.0890597804242
#   (0, 121105)	0.0600617447998
#   (0, 22354)	0.0547611832123
#   (0, 147557)	0.0374501528559
#   (0, 22027)	0.0504212740987
#   (0, 127144)	0.0843689591761
#   (0, 156525)	0.0190019434788
#   (0, 246564)	0.119642228669
#   (0, 280010)	0.0373999495414
#   (0, 180282)	0.0811034703072
#   (0, 191468)	0.0219406283814
#   (0, 103594)	0.0963881170864
#   (0, 30214)	0.129348908299
#   (0, 175121)	0.0898354776567
#   (0, 257580)	0.0190019434788
#   (0, 111377)	0.119642228669
#   (0, 243271)	0.137053533366
#   (0, 301542)	0.137053533366
#   (0, 242476)	0.113248602246
#   (0, 185627)	0.113248602246
#   (0, 185645)	0.119642228669
#   (0, 236538)	0.137053533366

# %%
X.shape
# Out:
# (997, 301759)

# %%
lsa=TruncatedSVD(n_components=30,n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=30, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([ 0.01487088,  0.00700224,  0.00128836, ...,  0.00025395,
#         0.00025395,  0.00025395])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# god
#
# edu
#
# one
#
# jesus
#
# would
#
# people
#
# sin
#
# church
#
# us
#
# com
#
# Concept 1:
# homosexuality
#
# homosexual
#
# people
#
# com
#
# bible
#
# say
#
# way
#
# faith
#
# says
#
# another
#
# Concept 2:
# god
#
# jesus
#
# 00 08 10
#
# christ
#
# 00 08 27
#
# 00 08 22
#
# time
#
# really
#
# lord
#
# doctrine
#
# Concept 3:
# god
#
# us
#
# 00 08 33
#
# sin
#
# one
#
# michael
#
# bible
#
# 00 08 44
#
# hell
#
# 00 08 04
#
# Concept 4:
# bible
#
# sin
#
# homosexuality
#
# first
#
# good
#
# lines
#
# re
#
# believe
#
# edu
#
# mean
#
# Concept 5:
# think
#
# hell
#
# 00 08 33
#
# one
#
# christ
#
# edu
#
# come
#
# subject
#
# mary
#
# homosexuality
#
# Concept 6:
# sin
#
# say
#
# love
#
# 10
#
# life
#
# subject
#
# mean
#
# believe
#
# mary
#
# 00 08 33
#
# Concept 7:
# like
#
# think
#
# believe
#
# christian
#
# question
#
# would
#
# read
#
# bible
#
# jesus
#
# christians
#
# Concept 8:
# com
#
# god
#
# would
#
# christianity
#
# us
#
# things
#
# article
#
# way
#
# law
#
# 00 08 22
#
# Concept 9:
# jesus
#
# church
#
# 00 08 44
#
# also
#
# man
#
# must
#
# 00 08 33
#
# say
#
# hell
#
# right
#
# Concept 10:
# jesus
#
# edu
#
# question
#
# christianity
#
# catholic
#
# subject re
#
# let
#
# 00 08 27
#
# many
#
# us
#
# Concept 11:
# also
#
# first
#
# things
#
# one
#
# church
#
# could
#
# way
#
# want
#
# 00 08 22
#
# edu
#
# Concept 12:
# jesus
#
# god
#
# said
#
# know
#
# 00 08 44
#
# church
#
# article apr
#
# 00 08 22
#
# christian
#
# christianity
#
# Concept 13:
# jesus
#
# even
#
# re
#
# doesn
#
# article
#
# say
#
# love
#
# life
#
# man
#
# something
#
# Concept 14:
# jesus
#
# believe
#
# bible
#
# rutgers
#
# hell
#
# 00 08 47
#
# ve
#
# 1993
#
# use
#
# law
#
# Concept 15:
# god
#
# say
#
# jesus
#
# 00 08 47
#
# university
#
# article
#
# edu
#
# also
#
# rutgers
#
# 00 08 10
#
# Concept 16:
# people
#
# 00 08 33
#
# even
#
# university
#
# question
#
# could
#
# christianity
#
# sin
#
# point
#
# lines
#
# Concept 17:
# com
#
# people
#
# subject
#
# 00 08 27
#
# fact
#
# right
#
# god
#
# think
#
# doesn
#
# mean
#
# Concept 18:
# think
#
# christian
#
# us
#
# said
#
# know
#
# true
#
# subject
#
# article
#
# tell
#
# person
#
# Concept 19:
# com
#
# would
#
# think
#
# christians
#
# apr
#
# might
#
# may
#
# good
#
# life
#
# law
#
# Concept 20:
# subject
#
# would
#
# christian
#
# people
#
# re
#
# really
#
# many
#
# 00 08 15
#
# organization
#
# truth
#
# Concept 21:
# subject re
#
# sin
#
# organization
#
# believe
#
# paul
#
# said
#
# good
#
# reason
#
# 00 08 44
#
# re
#
# Concept 22:
# 00 08 33
#
# would
#
# lines
#
# believe
#
# christian
#
# rutgers
#
# christ
#
# subject
#
# writes
#
# hell
#
# Concept 23:
# christ
#
# article
#
# com
#
# also
#
# christians
#
# edu
#
# subject
#
# jesus
#
# bible
#
# make
#
# Concept 24:
# one
#
# edu
#
# subject
#
# 00 08 15
#
# 00 08 27
#
# question
#
# church
#
# 00 08 22
#
# right
#
# 00 08 47
#
# Concept 25:
# christ
#
# good
#
# god
#
# christians
#
# father
#
# could
#
# subject re
#
# never
#
# question
#
# first
#
# Concept 26:
# god
#
# writes
#
# may
#
# believe
#
# 00 08 47
#
# com
#
# christian
#
# lines
#
# subject
#
# see
#
# Concept 27:
# organization
#
# christ
#
# com
#
# article
#
# us
#
# would
#
# people
#
# things
#
# free
#
# get
#
# Concept 28:
# think
#
# subject
#
# christians
#
# 00 08 47
#
# bible
#
# 1993
#
# 00 08 35
#
# life
#
# lines
#
# 00 08 22
#
# Concept 29:
# 00 08 44
#
# would
#
# rutgers edu
#
# think
#
# subject re
#
# re
#
# one
#
# 00 08 04
#
# article
#
# question

# %%
corpus[2]
# Out:
# u'From: whitsebd@nextwork.rose-hulman.edu (Bryan Whitsell)\nSubject: Re: "Accepting Jesus in your heart..."\nReply-To: whitsebd@nextwork.rose-hulman.edu\nOrganization: Computer Science Department at Rose-Hulman\nLines: 20\n\nstuff deleted ...\n\n> Religion (especially Christianity) is nothing more than a DRUG.\n> Some people use drugs as an escape from reality.  Christians inject\n> themselves with jeezus and live with that high. \n \nYour logic is falty.  If Christianity is a DRUG, and once we die we\ndie, then why would you be reluctant to embrase this drug so that\nwhile you are alive you enjoy yourself.\n\nI also question your overall motives for posting this article.  Why\nwould you waste your presious fews seconds on this earth posting your\nopinon to a group that will generally reject it.\n\nIf you die, never having acepting Christ as your savior, I hope you\nhave a fantastic life that it is all you evver dreamed because it is\nal of heaven you will ever know.\n\nIn Christ\'s Love,\nBryan\n'

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(1,3))
X=vectorizer.fit_transform(corpus)

# %%
X[0]
# Out:
# <1x301759 sparse matrix of type '<type 'numpy.float64'>'
# 	with 72 stored elements in Compressed Sparse Row format>

# %%
print X[0]
# Out:
#   (0, 296340)	0.123882389819
#   (0, 136773)	0.137053533366
#   (0, 121217)	0.137053533366
#   (0, 22469)	0.137053533366
#   (0, 147609)	0.137053533366
#   (0, 22212)	0.129348908299
#   (0, 127146)	0.123882389819
#   (0, 157376)	0.137053533366
#   (0, 246575)	0.137053533366
#   (0, 280276)	0.119642228669
#   (0, 180323)	0.119642228669
#   (0, 191744)	0.119642228669
#   (0, 103620)	0.137053533366
#   (0, 30216)	0.137053533366
#   (0, 175125)	0.137053533366
#   (0, 257962)	0.137053533366
#   (0, 111385)	0.137053533366
#   (0, 243273)	0.137053533366
#   (0, 301544)	0.137053533366
#   (0, 242492)	0.137053533366
#   (0, 185638)	0.137053533366
#   (0, 185647)	0.119642228669
#   (0, 236540)	0.137053533366
#   (0, 24033)	0.119642228669
#   (0, 296338)	0.119642228669
#   :	:
#   (0, 265758)	0.0686976091148
#   (0, 24016)	0.0975401027236
#   (0, 296233)	0.0301177950438
#   (0, 136715)	0.0890597804242
#   (0, 121105)	0.0600617447998
#   (0, 22354)	0.0547611832123
#   (0, 147557)	0.0374501528559
#   (0, 22027)	0.0504212740987
#   (0, 127144)	0.0843689591761
#   (0, 156525)	0.0190019434788
#   (0, 246564)	0.119642228669
#   (0, 280010)	0.0373999495414
#   (0, 180282)	0.0811034703072
#   (0, 191468)	0.0219406283814
#   (0, 103594)	0.0963881170864
#   (0, 30214)	0.129348908299
#   (0, 175121)	0.0898354776567
#   (0, 257580)	0.0190019434788
#   (0, 111377)	0.119642228669
#   (0, 243271)	0.137053533366
#   (0, 301542)	0.137053533366
#   (0, 242476)	0.113248602246
#   (0, 185627)	0.113248602246
#   (0, 185645)	0.119642228669
#   (0, 236538)	0.137053533366

# %%
X.shape
# Out:
# (997, 301759)

# %%
lsa=TruncatedSVD(n_components=27,n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=27, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([ 0.01487088,  0.00700224,  0.00128836, ...,  0.00025395,
#         0.00025395,  0.00025395])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# god
#
# edu
#
# one
#
# jesus
#
# would
#
# people
#
# sin
#
# church
#
# us
#
# com
#
# Concept 1:
# god
#
# lord
#
# hell
#
# love
#
# must
#
# 11
#
# 00 08 04
#
# life
#
# thing
#
# 00 08 07
#
# Concept 2:
# com
#
# article
#
# like
#
# writes
#
# christian
#
# christianity
#
# christians
#
# point
#
# subject
#
# hell
#
# Concept 3:
# homosexuality
#
# homosexual
#
# things
#
# people
#
# jesus
#
# subject
#
# think
#
# marriage
#
# much
#
# seems
#
# Concept 4:
# jesus
#
# one
#
# sin
#
# church
#
# 00 08 15
#
# things
#
# mary
#
# make
#
# 00 08 27
#
# think
#
# Concept 5:
# sin
#
# jesus
#
# subject
#
# like
#
# homosexuality
#
# never
#
# must
#
# lord
#
# would
#
# many
#
# Concept 6:
# would
#
# com
#
# say
#
# 1993
#
# answer
#
# us
#
# christian
#
# 00 08 35
#
# re
#
# apr
#
# Concept 7:
# jesus
#
# god
#
# 00 08 47
#
# way
#
# paul
#
# rutgers edu
#
# people
#
# university
#
# bible
#
# anyone
#
# Concept 8:
# god
#
# church
#
# article
#
# way
#
# bible
#
# re
#
# however
#
# 00 08 33
#
# one
#
# 00 08 15
#
# Concept 9:
# com
#
# bible
#
# believe
#
# church
#
# christ
#
# mary
#
# say
#
# truth
#
# first
#
# subject
#
# Concept 10:
# jesus
#
# life
#
# think
#
# christ
#
# re
#
# christianity
#
# 00 08 22
#
# faith
#
# says
#
# understand
#
# Concept 11:
# bible
#
# faith
#
# people
#
# com
#
# may
#
# hell
#
# never
#
# rutgers
#
# mary
#
# think
#
# Concept 12:
# know
#
# writes
#
# think
#
# bible
#
# two
#
# 00 08 47
#
# rutgers edu
#
# catholic
#
# son
#
# time
#
# Concept 13:
# one
#
# faith
#
# edu
#
# subject re
#
# re
#
# think
#
# 00 08 10
#
# 00 08 04
#
# university
#
# lord
#
# Concept 14:
# question
#
# writes
#
# way
#
# 1993
#
# christians
#
# 00 08 35
#
# also
#
# edu
#
# know
#
# christ
#
# Concept 15:
# god
#
# see
#
# question
#
# even
#
# time
#
# subject
#
# must
#
# way
#
# lord
#
# sin
#
# Concept 16:
# bible
#
# us
#
# subject re
#
# things
#
# organization
#
# subject
#
# know
#
# something
#
# mean
#
# 00 08 44
#
# Concept 17:
# christian
#
# people
#
# one
#
# believe
#
# even
#
# know
#
# truth
#
# god
#
# christians
#
# seems
#
# Concept 18:
# christ
#
# christians
#
# also
#
# life
#
# christian
#
# know
#
# 00 08 44
#
# jesus
#
# may
#
# lines
#
# Concept 19:
# people
#
# would
#
# also
#
# rutgers
#
# well
#
# subject
#
# believe
#
# says
#
# sin
#
# christian
#
# Concept 20:
# may
#
# us
#
# re
#
# life
#
# believe
#
# think
#
# jesus
#
# love
#
# writes
#
# faith
#
# Concept 21:
# us
#
# com
#
# like
#
# 00 08 35
#
# one
#
# life
#
# read
#
# rutgers
#
# want
#
# bible
#
# Concept 22:
# edu
#
# re
#
# organization
#
# christ
#
# believe
#
# subject re
#
# 00 08 33
#
# com
#
# things
#
# original
#
# Concept 23:
# god
#
# writes
#
# com
#
# organization
#
# people
#
# rutgers edu
#
# subject re
#
# jesus
#
# would
#
# lines
#
# Concept 24:
# 00 08 35
#
# subject re
#
# know
#
# 00 08 22
#
# may
#
# really
#
# com
#
# god
#
# true
#
# fact
#
# Concept 25:
# 1993
#
# people
#
# one
#
# question
#
# even
#
# right
#
# article
#
# christ
#
# still
#
# 00 08 47
#
# Concept 26:
# 00 08 22
#
# 00 08 33
#
# rutgers edu
#
# 00 08 04
#
# church
#
# christians
#
# jesus
#
# re
#
# may
#
# organization
